# %%
# %cd /content
# !git clone -b dev https://github.com/camenduru/MagicAnimate-hf

# !pip install -q diffusers==0.21.4 transformers==4.32.0 accelerate==0.22.0 omegaconf==2.3.0 einops==0.6.1 av gradio
# !pip install -q https://download.pytorch.org/whl/cu118/xformers-0.0.22.post4%2Bcu118-cp310-cp310-manylinux2014_x86_64.whl

# !apt -y install -qq aria2
BaseModelUrl = "https://huggingface.co/runwayml/stable-diffusion-v1-5"
BaseModelDir = "/content/MagicAnimate-hf/stable-diffusion-v1-5"
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {BaseModelUrl}/raw/main/model_index.json -d {BaseModelDir} -o model_index.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {BaseModelUrl}/resolve/main/vae/diffusion_pytorch_model.bin -d {BaseModelDir}/vae -o diffusion_pytorch_model.bin
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {BaseModelUrl}/raw/main/vae/config.json -d {BaseModelDir}/vae -o config.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {BaseModelUrl}/resolve/main/unet/diffusion_pytorch_model.bin -d {BaseModelDir}/unet -o diffusion_pytorch_model.bin
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {BaseModelUrl}/raw/main/unet/config.json -d {BaseModelDir}/unet -o config.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {BaseModelUrl}/raw/main/tokenizer/vocab.json -d {BaseModelDir}/tokenizer -o vocab.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {BaseModelUrl}/raw/main/tokenizer/tokenizer_config.json -d {BaseModelDir}/tokenizer -o tokenizer_config.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {BaseModelUrl}/raw/main/tokenizer/special_tokens_map.json -d {BaseModelDir}/tokenizer -o special_tokens_map.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {BaseModelUrl}/raw/main/tokenizer/merges.txt -d {BaseModelDir}/tokenizer -o merges.txt
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {BaseModelUrl}/resolve/main/text_encoder/pytorch_model.bin -d {BaseModelDir}/text_encoder -o pytorch_model.bin
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {BaseModelUrl}/raw/main/text_encoder/config.json -d {BaseModelDir}/text_encoder -o config.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {BaseModelUrl}/raw/main/scheduler/scheduler_config.json -d {BaseModelDir}/scheduler -o scheduler_config.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {BaseModelUrl}/resolve/main/safety_checker/pytorch_model.bin -d {BaseModelDir}/safety_checker -o pytorch_model.bin
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {BaseModelUrl}/raw/main/safety_checker/config.json -d {BaseModelDir}/safety_checker -o config.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {BaseModelUrl}/raw/main/feature_extractor/preprocessor_config.json -d {BaseModelDir}/feature_extractor -o preprocessor_config.json

# %cd /content/MagicAnimate-hf
# !python app.py
# Out:
# /content
# Cloning into 'MagicAnimate-hf'...
# remote: Enumerating objects: 142, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 142 (delta 20), reused 18 (delta 18), pack-reused 118
# Receiving objects: 100% (142/142), 5.51 MiB | 9.98 MiB/s, done.
# Resolving deltas: 100% (33/33), done.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 13.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.2/251.2 kB 11.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 9.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 5.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 1.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 910.4 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 913.4 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 862.2 kB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 915.5 kB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.9/302.9 kB 723.1 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 624.9 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 679.6 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.9/381.9 kB 677.6 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 658.0 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 634.1 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 727.8 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 845.4 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 603.6 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 616.2 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 644.9 kB/s eta 0:00:00
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Building wheel for ffmpy (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires kaleido, which is not installed.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.9.0 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.4/211.4 MB 5.7 MB/s eta 0:00:00
# The following additional packages will be installed:
#   libaria2-0 libc-ares2
# The following NEW packages will be installed:
#   aria2 libaria2-0 libc-ares2
# 0 upgraded, 3 newly installed, 0 to remove and 23 not upgraded.
# Need to get 1,513 kB of archives.
# After this operation, 5,441 kB of additional disk space will be used.
# Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 120903 files and directories currently installed.)
# Preparing to unpack .../libc-ares2_1.18.1-1ubuntu0.22.04.2_amd64.deb ...
# Unpacking libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.2) ...
# Selecting previously unselected package libaria2-0:amd64.
# Preparing to unpack .../libaria2-0_1.36.0-1_amd64.deb ...
# Unpacking libaria2-0:amd64 (1.36.0-1) ...
# Selecting previously unselected package aria2.
# Preparing to unpack .../aria2_1.36.0-1_amd64.deb ...
# Unpacking aria2 (1.36.0-1) ...
# Setting up libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.2) ...
# Setting up libaria2-0:amd64 (1.36.0-1) ...
# Setting up aria2 (1.36.0-1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 89d857|OK  |    66KiB/s|/content/MagicAnimate-hf/stable-diffusion-v1-5/model_index.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 74bb10|OK  |   225MiB/s|/content/MagicAnimate-hf/stable-diffusion-v1-5/vae/diffusion_pytorch_model.bin
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 216fad|OK  |    76KiB/s|/content/MagicAnimate-hf/stable-diffusion-v1-5/vae/config.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 391a0e|OK  |   190MiB/s|/content/MagicAnimate-hf/stable-diffusion-v1-5/unet/diffusion_pytorch_model.bin
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 22afed|OK  |    90KiB/s|/content/MagicAnimate-hf/stable-diffusion-v1-5/unet/config.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 2568ce|OK  |    13MiB/s|/content/MagicAnimate-hf/stable-diffusion-v1-5/tokenizer/vocab.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 10b603|OK  |    87KiB/s|/content/MagicAnimate-hf/stable-diffusion-v1-5/tokenizer/tokenizer_config.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 7e070d|OK  |    57KiB/s|/content/MagicAnimate-hf/stable-diffusion-v1-5/tokenizer/special_tokens_map.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# e92bfc|OK  |   9.4MiB/s|/content/MagicAnimate-hf/stable-diffusion-v1-5/tokenizer/merges.txt
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 94ec57|OK  |   280MiB/s|/content/MagicAnimate-hf/stable-diffusion-v1-5/text_encoder/pytorch_model.bin
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# c27f51|OK  |    75KiB/s|/content/MagicAnimate-hf/stable-diffusion-v1-5/text_encoder/config.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 52d0fe|OK  |    37KiB/s|/content/MagicAnimate-hf/stable-diffusion-v1-5/scheduler/scheduler_config.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# e03142|OK  |   242MiB/s|/content/MagicAnimate-hf/stable-diffusion-v1-5/safety_checker/pytorch_model.bin
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 57471d|OK  |   576KiB/s|/content/MagicAnimate-hf/stable-diffusion-v1-5/safety_checker/config.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 9bfe19|OK  |    25KiB/s|/content/MagicAnimate-hf/stable-diffusion-v1-5/feature_extractor/preprocessor_config.json
#
# Status Legend:
# (OK):download completed.
# /content/MagicAnimate-hf
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# 2023-12-12 18:28:25.508344: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-12 18:28:25.508394: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-12 18:28:25.508430: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-12 18:28:26.499299: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Fetching 5 files:   0% 0/5 [00:00<?, ?it/s]
# config.json: 100% 547/547 [00:00<00:00, 3.30MB/s]
#
# .gitattributes: 100% 1.46k/1.46k [00:00<00:00, 7.47MB/s]
# Fetching 5 files:  20% 1/5 [00:00<00:02,  1.82it/s]
# README.md: 100% 6.84k/6.84k [00:00<00:00, 34.1MB/s]
#
# diffusion_pytorch_model.bin:   0% 0.00/335M [00:00<?, ?B/s]
#
# diffusion_pytorch_model.safetensors:   0% 0.00/335M [00:00<?, ?B/s]
# diffusion_pytorch_model.bin:   3% 10.5M/335M [00:00<00:03, 87.2MB/s]
#
# diffusion_pytorch_model.safetensors:   3% 10.5M/335M [00:00<00:04, 71.6MB/s]
#
# diffusion_pytorch_model.safetensors:   9% 31.5M/335M [00:00<00:02, 134MB/s]
# diffusion_pytorch_model.bin:   9% 31.5M/335M [00:00<00:02, 120MB/s]
#
# diffusion_pytorch_model.safetensors:  16% 52.4M/335M [00:00<00:01, 162MB/s]
# diffusion_pytorch_model.bin:  16% 52.4M/335M [00:00<00:01, 154MB/s]
# diffusion_pytorch_model.bin:  22% 73.4M/335M [00:00<00:01, 171MB/s]
#
# diffusion_pytorch_model.safetensors:  22% 73.4M/335M [00:00<00:01, 164MB/s]
# diffusion_pytorch_model.bin:  28% 94.4M/335M [00:00<00:01, 155MB/s]
#
# diffusion_pytorch_model.safetensors:  28% 94.4M/335M [00:00<00:01, 149MB/s]
# diffusion_pytorch_model.bin:  34% 115M/335M [00:00<00:01, 160MB/s]
#
# diffusion_pytorch_model.safetensors:  34% 115M/335M [00:00<00:01, 150MB/s]
# diffusion_pytorch_model.bin:  41% 136M/335M [00:00<00:01, 156MB/s]
#
# diffusion_pytorch_model.safetensors:  41% 136M/335M [00:00<00:01, 147MB/s]
# diffusion_pytorch_model.bin:  47% 157M/335M [00:01<00:01, 155MB/s]
#
# diffusion_pytorch_model.safetensors:  47% 157M/335M [00:01<00:01, 153MB/s]
# diffusion_pytorch_model.bin:  53% 178M/335M [00:01<00:00, 158MB/s]
#
# diffusion_pytorch_model.safetensors:  53% 178M/335M [00:01<00:00, 158MB/s]
# diffusion_pytorch_model.bin:  60% 199M/335M [00:01<00:00, 156MB/s]
#
# diffusion_pytorch_model.safetensors:  60% 199M/335M [00:01<00:00, 162MB/s]
# diffusion_pytorch_model.bin:  66% 220M/335M [00:01<00:00, 156MB/s]
#
# diffusion_pytorch_model.safetensors:  66% 220M/335M [00:01<00:00, 161MB/s]
#
# diffusion_pytorch_model.safetensors:  72% 241M/335M [00:01<00:00, 163MB/s]
# diffusion_pytorch_model.bin:  72% 241M/335M [00:01<00:00, 155MB/s]
#
# diffusion_pytorch_model.safetensors:  78% 262M/335M [00:01<00:00, 159MB/s]
# diffusion_pytorch_model.bin:  78% 262M/335M [00:01<00:00, 154MB/s]
# diffusion_pytorch_model.bin:  85% 283M/335M [00:01<00:00, 157MB/s]
#
# diffusion_pytorch_model.safetensors:  85% 283M/335M [00:01<00:00, 155MB/s]
# diffusion_pytorch_model.bin:  91% 304M/335M [00:01<00:00, 160MB/s]
#
# diffusion_pytorch_model.safetensors:  91% 304M/335M [00:01<00:00, 149MB/s]
# diffusion_pytorch_model.bin:  97% 325M/335M [00:02<00:00, 150MB/s]
#
# diffusion_pytorch_model.bin: 100% 335M/335M [00:02<00:00, 149MB/s]
# diffusion_pytorch_model.safetensors: 100% 335M/335M [00:02<00:00, 147MB/s]
# Fetching 5 files: 100% 5/5 [00:02<00:00,  1.68it/s]
# Fetching 7 files:   0% 0/7 [00:00<?, ?it/s]
# .gitattributes: 100% 1.52k/1.52k [00:00<00:00, 8.55MB/s]
#
# appearance_encoder/config.json: 100% 1.79k/1.79k [00:00<00:00, 11.0MB/s]
#
# README.md: 100% 139/139 [00:00<00:00, 920kB/s]
# Fetching 7 files:  29% 2/7 [00:00<00:00, 18.27it/s]
# densepose_controlnet/config.json: 100% 1.33k/1.33k [00:00<00:00, 13.0MB/s]
#
# diffusion_pytorch_model.safetensors:   0% 0.00/3.43G [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0% 10.5M/3.43G [00:00<00:37, 91.5MB/s]
#
# diffusion_pytorch_model.safetensors:   0% 0.00/1.45G [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   1% 31.5M/3.43G [00:00<00:25, 135MB/s]
#
# diffusion_pytorch_model.safetensors:   1% 10.5M/1.45G [00:00<00:23, 60.9MB/s]
# diffusion_pytorch_model.safetensors:   2% 52.4M/3.43G [00:00<00:21, 160MB/s]
#
# diffusion_pytorch_model.safetensors:   2% 31.5M/1.45G [00:00<00:13, 107MB/s]
# diffusion_pytorch_model.safetensors:   2% 73.4M/3.43G [00:00<00:21, 154MB/s]
#
# diffusion_pytorch_model.safetensors:   4% 52.4M/1.45G [00:00<00:11, 118MB/s]
#
#
# temporal_attention.ckpt:   0% 0.00/5.11G [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   3% 94.4M/3.43G [00:00<00:23, 141MB/s]
#
# diffusion_pytorch_model.safetensors:   5% 73.4M/1.45G [00:00<00:10, 130MB/s]
# diffusion_pytorch_model.safetensors:   3% 115M/3.43G [00:00<00:22, 147MB/s]
#
# diffusion_pytorch_model.safetensors:   7% 94.4M/1.45G [00:00<00:09, 148MB/s]
# diffusion_pytorch_model.safetensors:   4% 136M/3.43G [00:00<00:21, 151MB/s]
#
# diffusion_pytorch_model.safetensors:   8% 115M/1.45G [00:00<00:08, 149MB/s]
#
#
# temporal_attention.ckpt:   0% 10.5M/5.11G [00:00<03:15, 26.0MB/s]
# diffusion_pytorch_model.safetensors:   5% 157M/3.43G [00:01<00:22, 147MB/s]
#
# diffusion_pytorch_model.safetensors:   9% 136M/1.45G [00:01<00:08, 149MB/s]
#
#
# temporal_attention.ckpt:   0% 21.0M/5.11G [00:00<02:00, 42.3MB/s]
# diffusion_pytorch_model.safetensors:   5% 178M/3.43G [00:01<00:23, 138MB/s]
#
# diffusion_pytorch_model.safetensors:  11% 157M/1.45G [00:01<00:09, 137MB/s]
#
#
# temporal_attention.ckpt:   1% 31.5M/5.11G [00:00<01:35, 53.2MB/s]
# diffusion_pytorch_model.safetensors:   6% 199M/3.43G [00:01<00:26, 123MB/s]
#
# diffusion_pytorch_model.safetensors:  12% 178M/1.45G [00:01<00:10, 122MB/s]
#
#
# temporal_attention.ckpt:   1% 52.4M/5.11G [00:00<01:10, 71.3MB/s]
# diffusion_pytorch_model.safetensors:   6% 220M/3.43G [00:01<00:28, 113MB/s]
#
# diffusion_pytorch_model.safetensors:  14% 199M/1.45G [00:01<00:11, 112MB/s]
#
#
# temporal_attention.ckpt:   1% 73.4M/5.11G [00:01<01:00, 83.0MB/s]
# diffusion_pytorch_model.safetensors:   7% 241M/3.43G [00:01<00:28, 112MB/s]
#
#
# temporal_attention.ckpt:   2% 83.9M/5.11G [00:01<01:01, 82.1MB/s]
#
# diffusion_pytorch_model.safetensors:  15% 220M/1.45G [00:01<00:11, 107MB/s]
#
#
# temporal_attention.ckpt:   2% 105M/5.11G [00:01<00:55, 89.8MB/s]
# diffusion_pytorch_model.safetensors:   8% 262M/3.43G [00:02<00:29, 108MB/s]
#
# diffusion_pytorch_model.safetensors:  17% 241M/1.45G [00:02<00:11, 108MB/s]
#
#
# temporal_attention.ckpt:   2% 115M/5.11G [00:01<00:55, 90.7MB/s]
#
#
# temporal_attention.ckpt:   2% 126M/5.11G [00:01<00:53, 93.0MB/s]
#
# diffusion_pytorch_model.safetensors:  18% 262M/1.45G [00:02<00:10, 113MB/s]
# diffusion_pytorch_model.safetensors:   8% 283M/3.43G [00:02<00:30, 103MB/s]
#
#
# temporal_attention.ckpt:   3% 136M/5.11G [00:01<00:53, 93.6MB/s]
#
# diffusion_pytorch_model.safetensors:  20% 283M/1.45G [00:02<00:10, 112MB/s]
#
#
# temporal_attention.ckpt:   3% 147M/5.11G [00:01<00:51, 95.5MB/s]
# diffusion_pytorch_model.safetensors:   9% 304M/3.43G [00:02<00:31, 99.6MB/s]
#
#
# temporal_attention.ckpt:   3% 157M/5.11G [00:01<00:52, 93.5MB/s]
# diffusion_pytorch_model.safetensors:   9% 315M/3.43G [00:02<00:31, 97.7MB/s]
#
# diffusion_pytorch_model.safetensors:  21% 304M/1.45G [00:02<00:10, 112MB/s]
#
#
# temporal_attention.ckpt:   3% 168M/5.11G [00:02<00:52, 94.3MB/s]
# diffusion_pytorch_model.safetensors:   9% 325M/3.43G [00:02<00:33, 92.2MB/s]
#
#
# temporal_attention.ckpt:   3% 178M/5.11G [00:02<00:51, 96.0MB/s]
#
# diffusion_pytorch_model.safetensors:  22% 325M/1.45G [00:02<00:10, 105MB/s]
# diffusion_pytorch_model.safetensors:  10% 336M/3.43G [00:02<00:35, 87.0MB/s]
#
#
# temporal_attention.ckpt:   4% 189M/5.11G [00:02<00:57, 85.3MB/s]
# diffusion_pytorch_model.safetensors:  10% 346M/3.43G [00:03<00:35, 87.7MB/s]
#
#
# temporal_attention.ckpt:   4% 199M/5.11G [00:02<00:56, 86.3MB/s]
#
# diffusion_pytorch_model.safetensors:  24% 346M/1.45G [00:03<00:11, 96.0MB/s]
# diffusion_pytorch_model.safetensors:  10% 357M/3.43G [00:03<00:36, 83.8MB/s]
#
#
# temporal_attention.ckpt:   4% 210M/5.11G [00:02<00:58, 84.3MB/s]
#
# diffusion_pytorch_model.safetensors:  25% 357M/1.45G [00:03<00:11, 93.8MB/s]
# diffusion_pytorch_model.safetensors:  11% 367M/3.43G [00:03<00:35, 86.7MB/s]
#
#
# temporal_attention.ckpt:   4% 220M/5.11G [00:02<00:55, 88.1MB/s]
# diffusion_pytorch_model.safetensors:  11% 377M/3.43G [00:03<00:34, 89.0MB/s]
#
# diffusion_pytorch_model.safetensors:  25% 367M/1.45G [00:03<00:12, 87.3MB/s]
#
#
# temporal_attention.ckpt:   5% 231M/5.11G [00:02<00:55, 87.3MB/s]
# diffusion_pytorch_model.safetensors:  11% 388M/3.43G [00:03<00:34, 88.3MB/s]
#
# diffusion_pytorch_model.safetensors:  26% 377M/1.45G [00:03<00:12, 86.5MB/s]
#
#
# temporal_attention.ckpt:   5% 241M/5.11G [00:02<00:54, 89.5MB/s]
# diffusion_pytorch_model.safetensors:  12% 398M/3.43G [00:03<00:33, 89.2MB/s]
#
# diffusion_pytorch_model.safetensors:  27% 388M/1.45G [00:03<00:12, 84.8MB/s]
#
#
# temporal_attention.ckpt:   5% 252M/5.11G [00:03<00:58, 83.0MB/s]
# diffusion_pytorch_model.safetensors:  12% 409M/3.43G [00:03<00:35, 86.2MB/s]
#
# diffusion_pytorch_model.safetensors:  28% 398M/1.45G [00:03<00:11, 87.4MB/s]
#
#
# temporal_attention.ckpt:   5% 262M/5.11G [00:03<00:59, 81.4MB/s]
# diffusion_pytorch_model.safetensors:  12% 419M/3.43G [00:03<00:35, 83.7MB/s]
#
# diffusion_pytorch_model.safetensors:  28% 409M/1.45G [00:03<00:11, 90.5MB/s]
#
#
# temporal_attention.ckpt:   5% 273M/5.11G [00:03<00:55, 86.5MB/s]
# diffusion_pytorch_model.safetensors:  13% 430M/3.43G [00:04<00:36, 82.6MB/s]
#
# diffusion_pytorch_model.safetensors:  29% 419M/1.45G [00:03<00:11, 87.7MB/s]
#
#
# temporal_attention.ckpt:   6% 283M/5.11G [00:03<00:57, 83.9MB/s]
#
# diffusion_pytorch_model.safetensors:  30% 430M/1.45G [00:04<00:11, 86.5MB/s]
# diffusion_pytorch_model.safetensors:  13% 440M/3.43G [00:04<00:37, 80.4MB/s]
#
#
# temporal_attention.ckpt:   6% 294M/5.11G [00:03<00:57, 84.3MB/s]
# diffusion_pytorch_model.safetensors:  13% 451M/3.43G [00:04<00:38, 77.7MB/s]
#
#
# temporal_attention.ckpt:   6% 304M/5.11G [00:03<00:58, 82.0MB/s]
#
# diffusion_pytorch_model.safetensors:  31% 451M/1.45G [00:04<00:10, 93.1MB/s]
# diffusion_pytorch_model.safetensors:  13% 461M/3.43G [00:04<00:38, 78.0MB/s]
#
#
# temporal_attention.ckpt:   6% 315M/5.11G [00:03<00:57, 83.8MB/s]
#
# diffusion_pytorch_model.safetensors:  32% 461M/1.45G [00:04<00:11, 86.0MB/s]
# diffusion_pytorch_model.safetensors:  14% 472M/3.43G [00:04<00:36, 79.9MB/s]
#
#
# temporal_attention.ckpt:   6% 325M/5.11G [00:03<00:58, 81.6MB/s]
#
# diffusion_pytorch_model.safetensors:  33% 472M/1.45G [00:04<00:11, 87.8MB/s]
# diffusion_pytorch_model.safetensors:  14% 482M/3.43G [00:04<00:36, 81.0MB/s]
#
#
# temporal_attention.ckpt:   7% 336M/5.11G [00:04<00:55, 85.3MB/s]
#
# diffusion_pytorch_model.safetensors:  33% 482M/1.45G [00:04<00:10, 90.7MB/s]
#
#
# temporal_attention.ckpt:   7% 346M/5.11G [00:04<00:55, 86.5MB/s]
#
# diffusion_pytorch_model.safetensors:  34% 493M/1.45G [00:04<00:10, 87.9MB/s]
# diffusion_pytorch_model.safetensors:  15% 503M/3.43G [00:04<00:33, 86.3MB/s]
#
#
# temporal_attention.ckpt:   7% 357M/5.11G [00:04<00:56, 83.8MB/s]
#
# diffusion_pytorch_model.safetensors:  35% 503M/1.45G [00:04<00:12, 78.1MB/s]
# diffusion_pytorch_model.safetensors:  15% 514M/3.43G [00:05<00:35, 82.1MB/s]
#
#
# temporal_attention.ckpt:   7% 367M/5.11G [00:04<00:55, 86.1MB/s]
#
# diffusion_pytorch_model.safetensors:  36% 514M/1.45G [00:05<00:11, 80.0MB/s]
#
#
# temporal_attention.ckpt:   7% 377M/5.11G [00:04<00:53, 88.5MB/s]
# diffusion_pytorch_model.safetensors:  15% 524M/3.43G [00:05<00:35, 81.2MB/s]
#
#
# temporal_attention.ckpt:   8% 388M/5.11G [00:04<00:53, 88.3MB/s]
#
# diffusion_pytorch_model.safetensors:  37% 535M/1.45G [00:05<00:10, 86.5MB/s]
# diffusion_pytorch_model.safetensors:  16% 535M/3.43G [00:05<00:40, 72.3MB/s]
#
#
# temporal_attention.ckpt:   8% 398M/5.11G [00:04<00:53, 87.8MB/s]
#
# diffusion_pytorch_model.safetensors:  38% 545M/1.45G [00:05<00:10, 87.2MB/s]
# diffusion_pytorch_model.safetensors:  16% 545M/3.43G [00:05<00:38, 75.8MB/s]
#
#
# temporal_attention.ckpt:   8% 409M/5.11G [00:04<00:53, 87.5MB/s]
# diffusion_pytorch_model.safetensors:  16% 556M/3.43G [00:05<00:37, 77.3MB/s]
#
#
# temporal_attention.ckpt:   8% 419M/5.11G [00:05<00:53, 88.4MB/s]
#
# diffusion_pytorch_model.safetensors:  39% 566M/1.45G [00:05<00:09, 88.7MB/s]
# diffusion_pytorch_model.safetensors:  17% 566M/3.43G [00:05<00:36, 77.7MB/s]
#
#
# temporal_attention.ckpt:   8% 430M/5.11G [00:05<00:53, 86.9MB/s]
#
# diffusion_pytorch_model.safetensors:  40% 577M/1.45G [00:05<00:09, 89.9MB/s]
# diffusion_pytorch_model.safetensors:  17% 577M/3.43G [00:05<00:36, 78.7MB/s]
#
#
# temporal_attention.ckpt:   9% 440M/5.11G [00:05<00:54, 85.0MB/s]
#
# diffusion_pytorch_model.safetensors:  41% 587M/1.45G [00:05<00:09, 90.7MB/s]
#
#
# temporal_attention.ckpt:   9% 451M/5.11G [00:05<00:56, 83.0MB/s]
#
# diffusion_pytorch_model.safetensors:  41% 598M/1.45G [00:05<00:09, 88.0MB/s]
# diffusion_pytorch_model.safetensors:  17% 598M/3.43G [00:06<00:32, 87.4MB/s]
#
# diffusion_pytorch_model.safetensors:  42% 608M/1.45G [00:06<00:10, 82.8MB/s]
#
#
# temporal_attention.ckpt:   9% 461M/5.11G [00:05<01:02, 73.8MB/s]
# diffusion_pytorch_model.safetensors:  18% 608M/3.43G [00:06<00:34, 82.6MB/s]
#
# diffusion_pytorch_model.safetensors:  43% 619M/1.45G [00:06<00:09, 83.5MB/s]
#
#
# temporal_attention.ckpt:   9% 472M/5.11G [00:05<00:59, 77.5MB/s]
# diffusion_pytorch_model.safetensors:  18% 619M/3.43G [00:06<00:34, 81.3MB/s]
#
# diffusion_pytorch_model.safetensors:  44% 629M/1.45G [00:06<00:10, 80.8MB/s]
# diffusion_pytorch_model.safetensors:  18% 629M/3.43G [00:06<00:34, 80.6MB/s]
#
#
# temporal_attention.ckpt:   9% 482M/5.11G [00:05<01:07, 68.8MB/s]
# diffusion_pytorch_model.safetensors:  19% 640M/3.43G [00:06<00:32, 85.9MB/s]
#
#
# temporal_attention.ckpt:  10% 493M/5.11G [00:06<01:01, 75.2MB/s]
#
# diffusion_pytorch_model.safetensors:  45% 650M/1.45G [00:06<00:08, 89.4MB/s]
# diffusion_pytorch_model.safetensors:  19% 650M/3.43G [00:06<00:32, 85.2MB/s]
#
#
# temporal_attention.ckpt:  10% 503M/5.11G [00:06<01:00, 76.7MB/s]
#
# diffusion_pytorch_model.safetensors:  46% 661M/1.45G [00:06<00:08, 88.6MB/s]
# diffusion_pytorch_model.safetensors:  19% 661M/3.43G [00:06<00:33, 82.0MB/s]
#
#
# temporal_attention.ckpt:  10% 514M/5.11G [00:06<00:59, 76.8MB/s]
#
# diffusion_pytorch_model.safetensors:  46% 671M/1.45G [00:06<00:09, 84.1MB/s]
# diffusion_pytorch_model.safetensors:  20% 671M/3.43G [00:07<00:37, 74.3MB/s]
#
#
# temporal_attention.ckpt:  10% 524M/5.11G [00:06<01:05, 69.9MB/s]
#
# Fetching 7 files:  29% 2/7 [00:11<00:00, 18.27it/s]
#
#
# temporal_attention.ckpt:  10% 535M/5.11G [00:11<10:40, 7.15MB/s]
# diffusion_pytorch_model.safetensors:  20% 682M/3.43G [00:11<06:36, 6.92MB/s]
#
# diffusion_pytorch_model.safetensors:  48% 692M/1.45G [00:12<01:48, 6.97MB/s]
# diffusion_pytorch_model.safetensors:  20% 692M/3.43G [00:12<05:14, 8.71MB/s]
#
#
# temporal_attention.ckpt:  11% 545M/5.11G [00:11<08:58, 8.48MB/s]
# diffusion_pytorch_model.safetensors:  20% 703M/3.43G [00:12<03:50, 11.9MB/s]
#
# diffusion_pytorch_model.safetensors:  49% 713M/1.45G [00:12<01:01, 12.0MB/s]
#
#
# temporal_attention.ckpt:  11% 556M/5.11G [00:11<06:45, 11.2MB/s]
# diffusion_pytorch_model.safetensors:  21% 713M/3.43G [00:12<02:48, 16.1MB/s]
#
# diffusion_pytorch_model.safetensors:  50% 724M/1.45G [00:12<00:47, 15.1MB/s]
#
# diffusion_pytorch_model.safetensors:  51% 734M/1.45G [00:12<00:37, 19.0MB/s]
#
#
# temporal_attention.ckpt:  11% 577M/5.11G [00:12<03:56, 19.2MB/s]
# diffusion_pytorch_model.safetensors:  21% 724M/3.43G [00:12<02:14, 20.2MB/s]
# diffusion_pytorch_model.safetensors:  21% 734M/3.43G [00:12<01:46, 25.4MB/s]
#
# diffusion_pytorch_model.safetensors:  52% 755M/1.45G [00:12<00:23, 28.8MB/s]
#
#
# temporal_attention.ckpt:  12% 598M/5.11G [00:12<02:46, 27.1MB/s]
#
# diffusion_pytorch_model.safetensors:  53% 765M/1.45G [00:12<00:19, 34.3MB/s]
# diffusion_pytorch_model.safetensors:  22% 744M/3.43G [00:13<01:32, 29.1MB/s]
#
# diffusion_pytorch_model.safetensors:  54% 776M/1.45G [00:13<00:16, 40.3MB/s]
#
#
# temporal_attention.ckpt:  12% 619M/5.11G [00:12<01:59, 37.5MB/s]
# diffusion_pytorch_model.safetensors:  22% 755M/3.43G [00:13<01:12, 36.8MB/s]
#
# diffusion_pytorch_model.safetensors:  55% 797M/1.45G [00:13<00:11, 57.7MB/s]
#
#
# temporal_attention.ckpt:  13% 640M/5.11G [00:12<01:32, 48.6MB/s]
# diffusion_pytorch_model.safetensors:  23% 776M/3.43G [00:13<00:48, 55.1MB/s]
#
# diffusion_pytorch_model.safetensors:  57% 818M/1.45G [00:13<00:08, 74.0MB/s]
#
#
# temporal_attention.ckpt:  13% 661M/5.11G [00:12<01:14, 60.0MB/s]
# diffusion_pytorch_model.safetensors:  23% 797M/3.43G [00:13<00:37, 70.7MB/s]
#
# diffusion_pytorch_model.safetensors:  58% 839M/1.45G [00:13<00:06, 87.1MB/s]
#
#
# temporal_attention.ckpt:  13% 682M/5.11G [00:13<01:01, 72.4MB/s]
# diffusion_pytorch_model.safetensors:  24% 818M/3.43G [00:13<00:31, 82.7MB/s]
#
# diffusion_pytorch_model.safetensors:  59% 860M/1.45G [00:13<00:06, 89.4MB/s]
# diffusion_pytorch_model.safetensors:  24% 828M/3.43G [00:13<00:31, 81.3MB/s]
#
#
# temporal_attention.ckpt:  14% 703M/5.11G [00:13<00:58, 75.2MB/s]
# diffusion_pytorch_model.safetensors:  24% 839M/3.43G [00:14<00:32, 79.9MB/s]
#
# diffusion_pytorch_model.safetensors:  61% 881M/1.45G [00:13<00:06, 89.5MB/s]
#
#
# temporal_attention.ckpt:  14% 713M/5.11G [00:13<00:57, 75.9MB/s]
# diffusion_pytorch_model.safetensors:  25% 849M/3.43G [00:14<00:30, 83.2MB/s]
#
#
# temporal_attention.ckpt:  14% 724M/5.11G [00:13<00:56, 77.2MB/s]
# diffusion_pytorch_model.safetensors:  25% 860M/3.43G [00:14<00:31, 82.5MB/s]
#
# diffusion_pytorch_model.safetensors:  62% 902M/1.45G [00:14<00:06, 86.7MB/s]
#
#
# temporal_attention.ckpt:  14% 734M/5.11G [00:13<00:56, 78.1MB/s]
# diffusion_pytorch_model.safetensors:  25% 870M/3.43G [00:14<00:30, 85.2MB/s]
#
# diffusion_pytorch_model.safetensors:  63% 912M/1.45G [00:14<00:06, 87.0MB/s]
#
#
# temporal_attention.ckpt:  15% 744M/5.11G [00:13<00:55, 79.1MB/s]
# diffusion_pytorch_model.safetensors:  26% 881M/3.43G [00:14<00:30, 83.4MB/s]
#
# diffusion_pytorch_model.safetensors:  64% 923M/1.45G [00:14<00:06, 86.6MB/s]
#
#
# temporal_attention.ckpt:  15% 755M/5.11G [00:14<00:52, 82.8MB/s]
# diffusion_pytorch_model.safetensors:  26% 891M/3.43G [00:14<00:31, 79.8MB/s]
#
# diffusion_pytorch_model.safetensors:  65% 933M/1.45G [00:14<00:05, 87.4MB/s]
#
#
# temporal_attention.ckpt:  15% 765M/5.11G [00:14<00:52, 82.9MB/s]
# diffusion_pytorch_model.safetensors:  26% 902M/3.43G [00:14<00:30, 82.5MB/s]
#
# diffusion_pytorch_model.safetensors:  65% 944M/1.45G [00:14<00:06, 82.9MB/s]
#
#
# temporal_attention.ckpt:  15% 776M/5.11G [00:14<00:53, 80.3MB/s]
# diffusion_pytorch_model.safetensors:  27% 912M/3.43G [00:14<00:29, 85.9MB/s]
#
# diffusion_pytorch_model.safetensors:  66% 954M/1.45G [00:14<00:05, 84.3MB/s]
#
# diffusion_pytorch_model.safetensors:  67% 965M/1.45G [00:14<00:05, 87.8MB/s]
#
# diffusion_pytorch_model.safetensors:  68% 986M/1.45G [00:15<00:03, 116MB/s]
#
#
# temporal_attention.ckpt:  15% 786M/5.11G [00:14<01:13, 59.1MB/s]
# diffusion_pytorch_model.safetensors:  27% 923M/3.43G [00:15<00:44, 56.3MB/s]
#
# diffusion_pytorch_model.safetensors:  70% 1.01G/1.45G [00:15<00:03, 116MB/s]
#
#
# temporal_attention.ckpt:  16% 807M/5.11G [00:14<00:58, 73.2MB/s]
# diffusion_pytorch_model.safetensors:  28% 944M/3.43G [00:15<00:31, 79.2MB/s]
# diffusion_pytorch_model.safetensors:  28% 954M/3.43G [00:15<00:30, 81.4MB/s]
#
#
# temporal_attention.ckpt:  16% 818M/5.11G [00:14<01:00, 71.2MB/s]
#
# diffusion_pytorch_model.safetensors:  71% 1.03G/1.45G [00:15<00:04, 103MB/s]
# diffusion_pytorch_model.safetensors:  28% 965M/3.43G [00:15<00:30, 82.1MB/s]
#
#
# temporal_attention.ckpt:  16% 828M/5.11G [00:15<00:58, 73.0MB/s]
# diffusion_pytorch_model.safetensors:  28% 975M/3.43G [00:15<00:29, 83.4MB/s]
#
#
# temporal_attention.ckpt:  16% 839M/5.11G [00:15<00:56, 75.2MB/s]
#
# diffusion_pytorch_model.safetensors:  73% 1.05G/1.45G [00:15<00:04, 97.8MB/s]
# diffusion_pytorch_model.safetensors:  29% 986M/3.43G [00:15<00:30, 80.6MB/s]
#
#
# temporal_attention.ckpt:  17% 849M/5.11G [00:15<00:53, 80.4MB/s]
#
# diffusion_pytorch_model.safetensors:  73% 1.06G/1.45G [00:15<00:04, 94.7MB/s]
# diffusion_pytorch_model.safetensors:  29% 996M/3.43G [00:16<00:28, 83.9MB/s]
#
#
# temporal_attention.ckpt:  17% 860M/5.11G [00:15<00:54, 78.6MB/s]
#
# diffusion_pytorch_model.safetensors:  74% 1.07G/1.45G [00:15<00:04, 92.7MB/s]
# diffusion_pytorch_model.safetensors:  29% 1.01G/3.43G [00:16<00:29, 83.4MB/s]
#
#
# temporal_attention.ckpt:  17% 870M/5.11G [00:15<00:51, 81.6MB/s]
#
# diffusion_pytorch_model.safetensors:  75% 1.08G/1.45G [00:16<00:04, 88.0MB/s]
# diffusion_pytorch_model.safetensors:  30% 1.02G/3.43G [00:16<00:28, 83.8MB/s]
#
#
# temporal_attention.ckpt:  17% 881M/5.11G [00:15<00:50, 84.5MB/s]
#
# diffusion_pytorch_model.safetensors:  75% 1.09G/1.45G [00:16<00:04, 83.1MB/s]
# diffusion_pytorch_model.safetensors:  30% 1.03G/3.43G [00:16<00:28, 83.9MB/s]
#
#
# temporal_attention.ckpt:  17% 891M/5.11G [00:15<00:51, 82.6MB/s]
#
# diffusion_pytorch_model.safetensors:  76% 1.10G/1.45G [00:16<00:03, 87.6MB/s]
# diffusion_pytorch_model.safetensors:  30% 1.04G/3.43G [00:16<00:28, 82.8MB/s]
#
#
# temporal_attention.ckpt:  18% 902M/5.11G [00:15<00:50, 82.7MB/s]
#
# diffusion_pytorch_model.safetensors:  77% 1.11G/1.45G [00:16<00:03, 88.1MB/s]
# diffusion_pytorch_model.safetensors:  31% 1.05G/3.43G [00:16<00:28, 84.0MB/s]
#
#
# temporal_attention.ckpt:  18% 912M/5.11G [00:16<00:52, 80.0MB/s]
#
# diffusion_pytorch_model.safetensors:  78% 1.12G/1.45G [00:16<00:03, 87.5MB/s]
# diffusion_pytorch_model.safetensors:  31% 1.06G/3.43G [00:16<00:27, 85.7MB/s]
#
#
# temporal_attention.ckpt:  18% 923M/5.11G [00:16<00:50, 82.5MB/s]
#
# diffusion_pytorch_model.safetensors:  78% 1.13G/1.45G [00:16<00:03, 84.3MB/s]
# diffusion_pytorch_model.safetensors:  31% 1.07G/3.43G [00:16<00:27, 84.8MB/s]
#
#
# temporal_attention.ckpt:  18% 933M/5.11G [00:16<00:52, 80.0MB/s]
#
# diffusion_pytorch_model.safetensors:  79% 1.14G/1.45G [00:16<00:03, 84.9MB/s]
# diffusion_pytorch_model.safetensors:  32% 1.08G/3.43G [00:17<00:26, 88.0MB/s]
#
#
# temporal_attention.ckpt:  18% 944M/5.11G [00:16<01:02, 66.2MB/s]
#
# diffusion_pytorch_model.safetensors:  80% 1.15G/1.45G [00:17<00:04, 62.5MB/s]
# diffusion_pytorch_model.safetensors:  32% 1.09G/3.43G [00:17<00:38, 60.8MB/s]
#
# diffusion_pytorch_model.safetensors:  81% 1.16G/1.45G [00:17<00:04, 58.9MB/s]
#
#
# temporal_attention.ckpt:  19% 954M/5.11G [00:16<01:19, 52.4MB/s]
# diffusion_pytorch_model.safetensors:  32% 1.10G/3.43G [00:17<00:39, 58.2MB/s]
#
#
# temporal_attention.ckpt:  19% 965M/5.11G [00:16<01:08, 60.6MB/s]
# diffusion_pytorch_model.safetensors:  32% 1.11G/3.43G [00:17<00:35, 65.2MB/s]
#
# diffusion_pytorch_model.safetensors:  82% 1.18G/1.45G [00:17<00:03, 75.3MB/s]
# diffusion_pytorch_model.safetensors:  33% 1.12G/3.43G [00:17<00:33, 69.6MB/s]
#
#
# temporal_attention.ckpt:  19% 975M/5.11G [00:17<01:07, 61.1MB/s]
#
# diffusion_pytorch_model.safetensors:  83% 1.20G/1.45G [00:17<00:03, 76.3MB/s]
# diffusion_pytorch_model.safetensors:  33% 1.13G/3.43G [00:17<00:29, 77.2MB/s]
#
# diffusion_pytorch_model.safetensors:  83% 1.21G/1.45G [00:17<00:03, 77.5MB/s]
#
#
# temporal_attention.ckpt:  19% 986M/5.11G [00:17<01:10, 58.3MB/s]
# diffusion_pytorch_model.safetensors:  33% 1.14G/3.43G [00:18<00:37, 60.4MB/s]
#
#
# temporal_attention.ckpt:  19% 996M/5.11G [00:17<01:11, 57.9MB/s]
#
# diffusion_pytorch_model.safetensors:  84% 1.22G/1.45G [00:18<00:03, 64.5MB/s]
# diffusion_pytorch_model.safetensors:  34% 1.15G/3.43G [00:18<00:33, 67.9MB/s]
#
#
# temporal_attention.ckpt:  20% 1.01G/5.11G [00:17<01:02, 66.0MB/s]
# diffusion_pytorch_model.safetensors:  34% 1.16G/3.43G [00:19<01:36, 23.4MB/s]
#
#
# temporal_attention.ckpt:  20% 1.02G/5.11G [00:18<02:52, 23.8MB/s]
#
# diffusion_pytorch_model.safetensors:  86% 1.24G/1.45G [00:19<00:07, 29.2MB/s]
# diffusion_pytorch_model.safetensors:  34% 1.17G/3.43G [00:19<01:18, 28.8MB/s]
#
#
# temporal_attention.ckpt:  20% 1.03G/5.11G [00:18<02:20, 29.1MB/s]
#
# diffusion_pytorch_model.safetensors:  86% 1.25G/1.45G [00:19<00:06, 32.8MB/s]
# diffusion_pytorch_model.safetensors:  35% 1.18G/3.43G [00:19<01:13, 30.6MB/s]
#
#
# temporal_attention.ckpt:  20% 1.04G/5.11G [00:19<02:12, 30.8MB/s]
#
# diffusion_pytorch_model.safetensors:  87% 1.26G/1.45G [00:19<00:05, 34.2MB/s]
#
#
# temporal_attention.ckpt:  21% 1.05G/5.11G [00:19<01:43, 39.1MB/s]
#
# diffusion_pytorch_model.safetensors:  88% 1.27G/1.45G [00:19<00:04, 39.2MB/s]
#
#
# temporal_attention.ckpt:  21% 1.06G/5.11G [00:19<01:24, 48.1MB/s]
# diffusion_pytorch_model.safetensors:  35% 1.21G/3.43G [00:20<00:49, 44.5MB/s]
#
# diffusion_pytorch_model.safetensors:  89% 1.28G/1.45G [00:19<00:03, 46.8MB/s]
#
#
# temporal_attention.ckpt:  21% 1.07G/5.11G [00:19<01:14, 54.5MB/s]
# diffusion_pytorch_model.safetensors:  35% 1.22G/3.43G [00:20<00:49, 44.4MB/s]
#
# diffusion_pytorch_model.safetensors:  89% 1.29G/1.45G [00:20<00:03, 49.3MB/s]
#
#
# temporal_attention.ckpt:  21% 1.08G/5.11G [00:19<01:09, 58.3MB/s]
#
#
# temporal_attention.ckpt:  21% 1.09G/5.11G [00:20<02:31, 26.5MB/s]
#
# diffusion_pytorch_model.safetensors:  91% 1.31G/1.45G [00:21<00:06, 20.6MB/s]
# diffusion_pytorch_model.safetensors:  36% 1.24G/3.43G [00:22<01:46, 20.5MB/s]
#
#
# temporal_attention.ckpt:  22% 1.10G/5.11G [00:21<03:26, 19.4MB/s]
# diffusion_pytorch_model.safetensors:  36% 1.25G/3.43G [00:22<01:28, 24.6MB/s]
#
#
# temporal_attention.ckpt:  22% 1.11G/5.11G [00:21<02:54, 22.9MB/s]
#
# diffusion_pytorch_model.safetensors:  92% 1.33G/1.45G [00:22<00:04, 28.2MB/s]
# diffusion_pytorch_model.safetensors:  37% 1.26G/3.43G [00:22<01:20, 27.0MB/s]
#
# diffusion_pytorch_model.safetensors:  93% 1.34G/1.45G [00:22<00:03, 31.4MB/s]
#
#
# temporal_attention.ckpt:  22% 1.12G/5.11G [00:21<02:34, 25.8MB/s]
# diffusion_pytorch_model.safetensors:  37% 1.27G/3.43G [00:22<01:07, 31.8MB/s]
#
# diffusion_pytorch_model.safetensors:  94% 1.35G/1.45G [00:22<00:02, 37.4MB/s]
#
#
# temporal_attention.ckpt:  22% 1.13G/5.11G [00:22<02:02, 32.6MB/s]
#
# diffusion_pytorch_model.safetensors:  94% 1.36G/1.45G [00:22<00:01, 44.2MB/s]
# diffusion_pytorch_model.safetensors:  37% 1.28G/3.43G [00:22<00:56, 37.8MB/s]
# diffusion_pytorch_model.safetensors:  38% 1.29G/3.43G [00:22<00:49, 42.9MB/s]
#
#
# temporal_attention.ckpt:  23% 1.15G/5.11G [00:22<01:22, 47.9MB/s]
#
# diffusion_pytorch_model.safetensors:  95% 1.37G/1.45G [00:22<00:01, 40.9MB/s]
#
#
# temporal_attention.ckpt:  23% 1.16G/5.11G [00:22<01:14, 53.2MB/s]
# diffusion_pytorch_model.safetensors:  38% 1.31G/3.43G [00:23<00:36, 58.2MB/s]
#
#
# temporal_attention.ckpt:  23% 1.17G/5.11G [00:22<01:05, 60.4MB/s]
# diffusion_pytorch_model.safetensors:  39% 1.32G/3.43G [00:24<01:38, 21.3MB/s]
#
# diffusion_pytorch_model.safetensors:  97% 1.39G/1.45G [00:24<00:02, 21.9MB/s]
#
#
# temporal_attention.ckpt:  23% 1.18G/5.11G [00:23<03:13, 20.3MB/s]
# diffusion_pytorch_model.safetensors:  39% 1.33G/3.43G [00:24<01:18, 26.7MB/s]
#
#
# temporal_attention.ckpt:  23% 1.20G/5.11G [00:24<02:30, 26.0MB/s]
#
# diffusion_pytorch_model.safetensors:  98% 1.42G/1.45G [00:24<00:00, 32.2MB/s]
# diffusion_pytorch_model.safetensors:  39% 1.35G/3.43G [00:24<00:51, 40.5MB/s]
#
# diffusion_pytorch_model.safetensors:  99% 1.44G/1.45G [00:24<00:00, 45.7MB/s]
#
#
# temporal_attention.ckpt:  24% 1.22G/5.11G [00:24<01:36, 40.5MB/s]
# diffusion_pytorch_model.safetensors: 100% 1.45G/1.45G [00:24<00:00, 58.1MB/s]
#
#
#
# temporal_attention.ckpt:  24% 1.24G/5.11G [00:24<01:10, 54.8MB/s]
# diffusion_pytorch_model.safetensors:  40% 1.38G/3.43G [00:25<00:32, 63.7MB/s]
# diffusion_pytorch_model.safetensors:  41% 1.41G/3.43G [00:25<00:24, 81.0MB/s]
# diffusion_pytorch_model.safetensors:  42% 1.43G/3.43G [00:25<00:19, 102MB/s]
#
#
# temporal_attention.ckpt:  24% 1.25G/5.11G [00:24<01:20, 47.8MB/s]
# diffusion_pytorch_model.safetensors:  42% 1.45G/3.43G [00:27<01:05, 30.4MB/s]
#
#
# temporal_attention.ckpt:  25% 1.26G/5.11G [00:26<03:28, 18.5MB/s]
# diffusion_pytorch_model.safetensors:  43% 1.46G/3.43G [00:27<00:58, 33.6MB/s]
#
#
# temporal_attention.ckpt:  25% 1.27G/5.11G [00:26<02:49, 22.6MB/s]
# diffusion_pytorch_model.safetensors:  43% 1.47G/3.43G [00:27<00:52, 37.1MB/s]
#
#
# temporal_attention.ckpt:  25% 1.28G/5.11G [00:26<02:23, 26.6MB/s]
# diffusion_pytorch_model.safetensors:  43% 1.49G/3.43G [00:27<00:37, 51.3MB/s]
#
#
# temporal_attention.ckpt:  25% 1.29G/5.11G [00:26<01:57, 32.4MB/s]
# diffusion_pytorch_model.safetensors:  44% 1.51G/3.43G [00:27<00:28, 67.5MB/s]
#
#
# temporal_attention.ckpt:  26% 1.31G/5.11G [00:27<01:20, 47.4MB/s]
# diffusion_pytorch_model.safetensors:  45% 1.53G/3.43G [00:27<00:23, 81.3MB/s]
#
#
# temporal_attention.ckpt:  26% 1.32G/5.11G [00:27<01:09, 54.3MB/s]
#
#
# temporal_attention.ckpt:  26% 1.33G/5.11G [00:27<01:03, 59.7MB/s]
# diffusion_pytorch_model.safetensors:  45% 1.55G/3.43G [00:27<00:20, 92.2MB/s]
#
#
# temporal_attention.ckpt:  26% 1.35G/5.11G [00:27<00:46, 80.0MB/s]
# diffusion_pytorch_model.safetensors:  46% 1.57G/3.43G [00:28<00:17, 106MB/s]
#
#
# temporal_attention.ckpt:  27% 1.37G/5.11G [00:27<00:39, 94.7MB/s]
# diffusion_pytorch_model.safetensors:  46% 1.59G/3.43G [00:28<00:16, 114MB/s]
# diffusion_pytorch_model.safetensors:  47% 1.61G/3.43G [00:28<00:14, 125MB/s]
#
#
# temporal_attention.ckpt:  27% 1.39G/5.11G [00:27<00:35, 103MB/s]
# diffusion_pytorch_model.safetensors:  48% 1.64G/3.43G [00:28<00:13, 131MB/s]
#
#
# temporal_attention.ckpt:  28% 1.42G/5.11G [00:27<00:31, 119MB/s]
# diffusion_pytorch_model.safetensors:  48% 1.66G/3.43G [00:28<00:12, 139MB/s]
#
#
# temporal_attention.ckpt:  28% 1.44G/5.11G [00:28<00:29, 123MB/s]
# diffusion_pytorch_model.safetensors:  49% 1.68G/3.43G [00:28<00:11, 146MB/s]
#
#
# temporal_attention.ckpt:  29% 1.46G/5.11G [00:28<00:28, 128MB/s]
# diffusion_pytorch_model.safetensors:  50% 1.70G/3.43G [00:28<00:11, 145MB/s]
#
#
# temporal_attention.ckpt:  29% 1.48G/5.11G [00:28<00:26, 135MB/s]
# diffusion_pytorch_model.safetensors:  50% 1.72G/3.43G [00:29<00:11, 151MB/s]
#
#
# temporal_attention.ckpt:  29% 1.50G/5.11G [00:28<00:26, 138MB/s]
# diffusion_pytorch_model.safetensors:  51% 1.74G/3.43G [00:29<00:11, 151MB/s]
#
#
# temporal_attention.ckpt:  30% 1.52G/5.11G [00:28<00:26, 137MB/s]
# diffusion_pytorch_model.safetensors:  51% 1.76G/3.43G [00:29<00:10, 156MB/s]
#
#
# temporal_attention.ckpt:  30% 1.54G/5.11G [00:28<00:25, 142MB/s]
# diffusion_pytorch_model.safetensors:  52% 1.78G/3.43G [00:29<00:10, 155MB/s]
#
#
# temporal_attention.ckpt:  31% 1.56G/5.11G [00:28<00:26, 136MB/s]
# diffusion_pytorch_model.safetensors:  53% 1.80G/3.43G [00:29<00:11, 144MB/s]
#
#
# temporal_attention.ckpt:  31% 1.58G/5.11G [00:29<00:27, 130MB/s]
# diffusion_pytorch_model.safetensors:  53% 1.82G/3.43G [00:29<00:11, 141MB/s]
#
#
# temporal_attention.ckpt:  31% 1.60G/5.11G [00:29<00:28, 124MB/s]
# diffusion_pytorch_model.safetensors:  54% 1.85G/3.43G [00:29<00:11, 134MB/s]
# diffusion_pytorch_model.safetensors:  54% 1.87G/3.43G [00:30<00:12, 129MB/s]
#
#
# temporal_attention.ckpt:  32% 1.63G/5.11G [00:29<00:30, 115MB/s]
# diffusion_pytorch_model.safetensors:  55% 1.89G/3.43G [00:30<00:12, 128MB/s]
#
#
# temporal_attention.ckpt:  32% 1.65G/5.11G [00:31<01:33, 37.2MB/s]
# diffusion_pytorch_model.safetensors:  56% 1.91G/3.43G [00:31<00:38, 39.1MB/s]
#
#
# temporal_attention.ckpt:  33% 1.67G/5.11G [00:31<01:10, 48.7MB/s]
# diffusion_pytorch_model.safetensors:  56% 1.93G/3.43G [00:31<00:29, 50.6MB/s]
#
#
# temporal_attention.ckpt:  33% 1.69G/5.11G [00:31<00:56, 61.1MB/s]
# diffusion_pytorch_model.safetensors:  57% 1.95G/3.43G [00:32<00:23, 63.4MB/s]
#
#
# temporal_attention.ckpt:  33% 1.71G/5.11G [00:31<00:46, 73.8MB/s]
# diffusion_pytorch_model.safetensors:  58% 1.97G/3.43G [00:32<00:20, 72.0MB/s]
#
#
# temporal_attention.ckpt:  34% 1.73G/5.11G [00:31<00:42, 78.7MB/s]
# diffusion_pytorch_model.safetensors:  58% 1.99G/3.43G [00:32<00:17, 81.8MB/s]
#
#
# temporal_attention.ckpt:  34% 1.75G/5.11G [00:31<00:38, 86.7MB/s]
# diffusion_pytorch_model.safetensors:  59% 2.01G/3.43G [00:32<00:15, 91.9MB/s]
#
#
# temporal_attention.ckpt:  35% 1.77G/5.11G [00:31<00:35, 94.4MB/s]
# diffusion_pytorch_model.safetensors:  59% 2.03G/3.43G [00:32<00:14, 99.1MB/s]
#
#
# temporal_attention.ckpt:  35% 1.79G/5.11G [00:32<00:32, 103MB/s]
# diffusion_pytorch_model.safetensors:  60% 2.06G/3.43G [00:32<00:13, 105MB/s]
#
#
# temporal_attention.ckpt:  35% 1.81G/5.11G [00:32<00:30, 107MB/s]
# diffusion_pytorch_model.safetensors:  61% 2.08G/3.43G [00:33<00:12, 111MB/s]
#
#
# temporal_attention.ckpt:  36% 1.84G/5.11G [00:32<00:29, 112MB/s]
#
#
# temporal_attention.ckpt:  36% 1.86G/5.11G [00:32<00:27, 119MB/s]
# diffusion_pytorch_model.safetensors:  61% 2.10G/3.43G [00:33<00:13, 99.3MB/s]
# diffusion_pytorch_model.safetensors:  62% 2.12G/3.43G [00:33<00:14, 87.5MB/s]
#
#
# temporal_attention.ckpt:  37% 1.88G/5.11G [00:32<00:34, 94.1MB/s]
# diffusion_pytorch_model.safetensors:  62% 2.14G/3.43G [00:33<00:13, 99.1MB/s]
#
#
# temporal_attention.ckpt:  37% 1.90G/5.11G [00:33<00:34, 92.5MB/s]
# diffusion_pytorch_model.safetensors:  63% 2.16G/3.43G [00:33<00:12, 102MB/s]
#
#
# temporal_attention.ckpt:  38% 1.93G/5.11G [00:33<00:26, 118MB/s]
#
#
# temporal_attention.ckpt:  38% 1.95G/5.11G [00:33<00:24, 131MB/s]
#
#
# temporal_attention.ckpt:  39% 1.97G/5.11G [00:33<00:22, 142MB/s]
# diffusion_pytorch_model.safetensors:  64% 2.18G/3.43G [00:34<00:14, 87.6MB/s]
#
#
# temporal_attention.ckpt:  39% 1.99G/5.11G [00:33<00:20, 153MB/s]
# diffusion_pytorch_model.safetensors:  64% 2.19G/3.43G [00:34<00:13, 90.1MB/s]
# diffusion_pytorch_model.safetensors:  64% 2.20G/3.43G [00:35<00:47, 25.8MB/s]
#
#
# temporal_attention.ckpt:  39% 2.01G/5.11G [00:35<01:22, 37.7MB/s]
# diffusion_pytorch_model.safetensors:  65% 2.22G/3.43G [00:36<00:33, 36.4MB/s]
#
#
# temporal_attention.ckpt:  40% 2.03G/5.11G [00:35<01:06, 46.5MB/s]
# diffusion_pytorch_model.safetensors:  65% 2.23G/3.43G [00:36<00:28, 41.9MB/s]
# diffusion_pytorch_model.safetensors:  65% 2.24G/3.43G [00:36<00:24, 48.0MB/s]
#
#
# temporal_attention.ckpt:  40% 2.06G/5.11G [00:35<00:55, 54.8MB/s]
# diffusion_pytorch_model.safetensors:  66% 2.25G/3.43G [00:36<00:21, 54.7MB/s]
# diffusion_pytorch_model.safetensors:  66% 2.26G/3.43G [00:36<00:18, 61.4MB/s]
#
#
# temporal_attention.ckpt:  41% 2.08G/5.11G [00:35<00:48, 62.9MB/s]
# diffusion_pytorch_model.safetensors:  66% 2.28G/3.43G [00:36<00:17, 67.8MB/s]
# diffusion_pytorch_model.safetensors:  67% 2.29G/3.43G [00:36<00:16, 70.5MB/s]
#
#
# temporal_attention.ckpt:  41% 2.10G/5.11G [00:36<00:44, 68.0MB/s]
# diffusion_pytorch_model.safetensors:  67% 2.31G/3.43G [00:36<00:12, 86.3MB/s]
#
#
# temporal_attention.ckpt:  41% 2.12G/5.11G [00:36<00:36, 81.7MB/s]
# diffusion_pytorch_model.safetensors:  68% 2.32G/3.43G [00:37<00:12, 89.6MB/s]
#
#
# temporal_attention.ckpt:  42% 2.14G/5.11G [00:36<00:33, 88.0MB/s]
# diffusion_pytorch_model.safetensors:  68% 2.33G/3.43G [00:37<00:12, 87.1MB/s]
#
#
# temporal_attention.ckpt:  42% 2.16G/5.11G [00:36<00:30, 95.2MB/s]
# diffusion_pytorch_model.safetensors:  69% 2.35G/3.43G [00:37<00:10, 101MB/s]
# diffusion_pytorch_model.safetensors:  69% 2.37G/3.43G [00:37<00:08, 119MB/s]
#
#
# temporal_attention.ckpt:  43% 2.18G/5.11G [00:36<00:28, 103MB/s]
# diffusion_pytorch_model.safetensors:  70% 2.39G/3.43G [00:37<00:07, 130MB/s]
#
#
# temporal_attention.ckpt:  43% 2.20G/5.11G [00:36<00:25, 116MB/s]
# diffusion_pytorch_model.safetensors:  70% 2.41G/3.43G [00:37<00:07, 138MB/s]
#
#
# temporal_attention.ckpt:  43% 2.22G/5.11G [00:37<00:22, 126MB/s]
# diffusion_pytorch_model.safetensors:  71% 2.43G/3.43G [00:37<00:06, 146MB/s]
#
#
# temporal_attention.ckpt:  44% 2.24G/5.11G [00:37<00:21, 134MB/s]
#
#
# temporal_attention.ckpt:  44% 2.26G/5.11G [00:37<00:19, 145MB/s]
# diffusion_pytorch_model.safetensors:  72% 2.45G/3.43G [00:38<00:06, 145MB/s]
#
#
# temporal_attention.ckpt:  45% 2.29G/5.11G [00:37<00:19, 148MB/s]
# diffusion_pytorch_model.safetensors:  72% 2.47G/3.43G [00:38<00:06, 143MB/s]
#
#
# temporal_attention.ckpt:  45% 2.31G/5.11G [00:37<00:17, 157MB/s]
# diffusion_pytorch_model.safetensors:  73% 2.50G/3.43G [00:38<00:06, 147MB/s]
#
#
# temporal_attention.ckpt:  46% 2.33G/5.11G [00:37<00:18, 152MB/s]
# diffusion_pytorch_model.safetensors:  73% 2.52G/3.43G [00:38<00:06, 148MB/s]
#
#
# temporal_attention.ckpt:  46% 2.35G/5.11G [00:37<00:20, 136MB/s]
# diffusion_pytorch_model.safetensors:  74% 2.54G/3.43G [00:38<00:06, 133MB/s]
#
#
# temporal_attention.ckpt:  46% 2.37G/5.11G [00:38<00:19, 138MB/s]
# diffusion_pytorch_model.safetensors:  75% 2.56G/3.43G [00:38<00:06, 135MB/s]
#
#
# temporal_attention.ckpt:  47% 2.39G/5.11G [00:38<00:20, 130MB/s]
# diffusion_pytorch_model.safetensors:  75% 2.58G/3.43G [00:38<00:06, 128MB/s]
#
#
# temporal_attention.ckpt:  47% 2.41G/5.11G [00:38<00:20, 129MB/s]
# diffusion_pytorch_model.safetensors:  76% 2.60G/3.43G [00:39<00:06, 126MB/s]
#
#
# temporal_attention.ckpt:  48% 2.43G/5.11G [00:38<00:20, 133MB/s]
# diffusion_pytorch_model.safetensors:  76% 2.62G/3.43G [00:39<00:06, 127MB/s]
#
#
# temporal_attention.ckpt:  48% 2.45G/5.11G [00:38<00:21, 126MB/s]
# diffusion_pytorch_model.safetensors:  77% 2.64G/3.43G [00:39<00:06, 127MB/s]
#
#
# temporal_attention.ckpt:  48% 2.47G/5.11G [00:38<00:21, 124MB/s]
# diffusion_pytorch_model.safetensors:  78% 2.66G/3.43G [00:39<00:05, 128MB/s]
#
#
# temporal_attention.ckpt:  49% 2.50G/5.11G [00:39<00:19, 131MB/s]
# diffusion_pytorch_model.safetensors:  78% 2.68G/3.43G [00:39<00:05, 130MB/s]
#
#
# temporal_attention.ckpt:  49% 2.52G/5.11G [00:39<00:20, 129MB/s]
# diffusion_pytorch_model.safetensors:  79% 2.71G/3.43G [00:39<00:05, 126MB/s]
#
#
# temporal_attention.ckpt:  50% 2.54G/5.11G [00:39<00:20, 125MB/s]
# diffusion_pytorch_model.safetensors:  80% 2.73G/3.43G [00:40<00:05, 128MB/s]
#
#
# temporal_attention.ckpt:  50% 2.56G/5.11G [00:39<00:21, 121MB/s]
# diffusion_pytorch_model.safetensors:  80% 2.75G/3.43G [00:40<00:05, 129MB/s]
# diffusion_pytorch_model.safetensors:  81% 2.77G/3.43G [00:40<00:05, 126MB/s]
#
#
# temporal_attention.ckpt:  50% 2.58G/5.11G [00:39<00:21, 119MB/s]
#
#
# temporal_attention.ckpt:  51% 2.60G/5.11G [00:39<00:19, 126MB/s]
# diffusion_pytorch_model.safetensors:  81% 2.79G/3.43G [00:40<00:05, 123MB/s]
#
#
# temporal_attention.ckpt:  51% 2.62G/5.11G [00:40<00:18, 131MB/s]
# diffusion_pytorch_model.safetensors:  82% 2.81G/3.43G [00:40<00:05, 119MB/s]
#
#
# temporal_attention.ckpt:  52% 2.64G/5.11G [00:40<00:19, 127MB/s]
# diffusion_pytorch_model.safetensors:  83% 2.83G/3.43G [00:40<00:04, 129MB/s]
#
#
# temporal_attention.ckpt:  52% 2.66G/5.11G [00:40<00:19, 125MB/s]
# diffusion_pytorch_model.safetensors:  83% 2.85G/3.43G [00:41<00:04, 129MB/s]
#
#
# temporal_attention.ckpt:  53% 2.68G/5.11G [00:40<00:19, 128MB/s]
# diffusion_pytorch_model.safetensors:  84% 2.87G/3.43G [00:41<00:04, 129MB/s]
#
#
# temporal_attention.ckpt:  53% 2.71G/5.11G [00:40<00:19, 125MB/s]
# diffusion_pytorch_model.safetensors:  84% 2.89G/3.43G [00:41<00:04, 124MB/s]
#
#
# temporal_attention.ckpt:  53% 2.73G/5.11G [00:40<00:18, 127MB/s]
# diffusion_pytorch_model.safetensors:  85% 2.92G/3.43G [00:41<00:04, 121MB/s]
#
#
# temporal_attention.ckpt:  54% 2.75G/5.11G [00:41<00:19, 124MB/s]
# diffusion_pytorch_model.safetensors:  86% 2.94G/3.43G [00:41<00:04, 122MB/s]
#
#
# temporal_attention.ckpt:  54% 2.77G/5.11G [00:41<00:20, 116MB/s]
# diffusion_pytorch_model.safetensors:  86% 2.96G/3.43G [00:42<00:04, 112MB/s]
#
#
# temporal_attention.ckpt:  55% 2.79G/5.11G [00:41<00:21, 111MB/s]
# diffusion_pytorch_model.safetensors:  87% 2.98G/3.43G [00:42<00:04, 110MB/s]
#
#
# temporal_attention.ckpt:  55% 2.81G/5.11G [00:41<00:21, 108MB/s]
# diffusion_pytorch_model.safetensors:  87% 3.00G/3.43G [00:42<00:04, 107MB/s]
#
#
# temporal_attention.ckpt:  55% 2.83G/5.11G [00:41<00:22, 103MB/s]
# diffusion_pytorch_model.safetensors:  88% 3.02G/3.43G [00:42<00:04, 102MB/s]
#
#
# temporal_attention.ckpt:  56% 2.84G/5.11G [00:42<00:22, 103MB/s]
# diffusion_pytorch_model.safetensors:  88% 3.03G/3.43G [00:42<00:04, 96.8MB/s]
#
#
# temporal_attention.ckpt:  56% 2.85G/5.11G [00:43<01:39, 22.8MB/s]
#
#
# temporal_attention.ckpt:  56% 2.86G/5.11G [00:46<03:00, 12.4MB/s]
#
#
# temporal_attention.ckpt:  56% 2.88G/5.11G [00:46<01:55, 19.4MB/s]
# diffusion_pytorch_model.safetensors:  89% 3.04G/3.43G [00:46<00:33, 11.4MB/s]
#
#
# temporal_attention.ckpt:  57% 2.89G/5.11G [00:46<01:38, 22.5MB/s]
# diffusion_pytorch_model.safetensors:  89% 3.06G/3.43G [00:47<00:21, 16.9MB/s]
#
#
# temporal_attention.ckpt:  57% 2.90G/5.11G [00:46<01:22, 26.9MB/s]
# diffusion_pytorch_model.safetensors:  90% 3.08G/3.43G [00:47<00:14, 24.3MB/s]
#
#
# temporal_attention.ckpt:  57% 2.92G/5.11G [00:46<01:08, 32.1MB/s]
# diffusion_pytorch_model.safetensors:  91% 3.10G/3.43G [00:47<00:09, 33.3MB/s]
#
#
# temporal_attention.ckpt:  58% 2.95G/5.11G [00:46<00:39, 54.5MB/s]
# diffusion_pytorch_model.safetensors:  91% 3.12G/3.43G [00:47<00:07, 41.4MB/s]
#
#
# temporal_attention.ckpt:  58% 2.96G/5.11G [00:47<00:36, 59.7MB/s]
# diffusion_pytorch_model.safetensors:  92% 3.15G/3.43G [00:47<00:05, 53.4MB/s]
#
#
# temporal_attention.ckpt:  58% 2.98G/5.11G [00:47<00:28, 75.2MB/s]
# diffusion_pytorch_model.safetensors:  92% 3.17G/3.43G [00:47<00:03, 66.6MB/s]
#
#
# temporal_attention.ckpt:  59% 3.00G/5.11G [00:47<00:23, 91.4MB/s]
# diffusion_pytorch_model.safetensors:  93% 3.19G/3.43G [00:48<00:02, 81.2MB/s]
#
#
# temporal_attention.ckpt:  59% 3.02G/5.11G [00:47<00:20, 104MB/s]
# diffusion_pytorch_model.safetensors:  94% 3.21G/3.43G [00:48<00:02, 95.3MB/s]
#
#
# temporal_attention.ckpt:  60% 3.04G/5.11G [00:47<00:17, 119MB/s]
# diffusion_pytorch_model.safetensors:  94% 3.23G/3.43G [00:48<00:01, 107MB/s]
#
#
# temporal_attention.ckpt:  60% 3.06G/5.11G [00:47<00:15, 131MB/s]
#
#
# temporal_attention.ckpt:  60% 3.08G/5.11G [00:47<00:14, 141MB/s]
# diffusion_pytorch_model.safetensors:  95% 3.25G/3.43G [00:48<00:01, 114MB/s]
#
#
# temporal_attention.ckpt:  61% 3.10G/5.11G [00:47<00:13, 145MB/s]
# diffusion_pytorch_model.safetensors:  95% 3.27G/3.43G [00:48<00:01, 124MB/s]
#
#
# temporal_attention.ckpt:  61% 3.12G/5.11G [00:48<00:13, 150MB/s]
# diffusion_pytorch_model.safetensors:  96% 3.29G/3.43G [00:48<00:01, 128MB/s]
# diffusion_pytorch_model.safetensors:  97% 3.31G/3.43G [00:48<00:00, 140MB/s]
#
#
# temporal_attention.ckpt:  62% 3.15G/5.11G [00:48<00:14, 133MB/s]
# diffusion_pytorch_model.safetensors:  97% 3.33G/3.43G [00:49<00:00, 131MB/s]
#
#
# temporal_attention.ckpt:  62% 3.17G/5.11G [00:48<00:15, 129MB/s]
# diffusion_pytorch_model.safetensors:  98% 3.36G/3.43G [00:49<00:00, 134MB/s]
#
#
# temporal_attention.ckpt:  62% 3.19G/5.11G [00:48<00:14, 132MB/s]
# diffusion_pytorch_model.safetensors:  98% 3.38G/3.43G [00:49<00:00, 111MB/s]
#
#
# temporal_attention.ckpt:  63% 3.21G/5.11G [00:48<00:18, 105MB/s]
# diffusion_pytorch_model.safetensors:  99% 3.40G/3.43G [00:49<00:00, 97.2MB/s]
#
#
# temporal_attention.ckpt:  63% 3.23G/5.11G [00:49<00:19, 96.1MB/s]
# diffusion_pytorch_model.safetensors: 100% 3.42G/3.43G [00:49<00:00, 105MB/s]
#
#
# diffusion_pytorch_model.safetensors: 100% 3.43G/3.43G [00:50<00:00, 68.5MB/s]
# Fetching 7 files:  57% 4/7 [00:50<00:44, 14.82s/it]
#
#
# temporal_attention.ckpt:  64% 3.27G/5.11G [00:49<00:16, 111MB/s]
#
#
# temporal_attention.ckpt:  64% 3.29G/5.11G [00:49<00:16, 113MB/s]
#
#
# temporal_attention.ckpt:  65% 3.31G/5.11G [00:49<00:13, 129MB/s]
#
#
# temporal_attention.ckpt:  65% 3.33G/5.11G [00:51<00:41, 42.7MB/s]
#
#
# temporal_attention.ckpt:  66% 3.36G/5.11G [00:51<00:31, 55.6MB/s]
#
#
# temporal_attention.ckpt:  66% 3.38G/5.11G [00:51<00:27, 63.5MB/s]
#
#
# temporal_attention.ckpt:  67% 3.41G/5.11G [00:51<00:19, 87.8MB/s]
#
#
# temporal_attention.ckpt:  67% 3.44G/5.11G [00:51<00:14, 112MB/s]
#
#
# temporal_attention.ckpt:  68% 3.46G/5.11G [00:51<00:13, 126MB/s]
#
#
# temporal_attention.ckpt:  68% 3.48G/5.11G [00:51<00:12, 134MB/s]
#
#
# temporal_attention.ckpt:  69% 3.50G/5.11G [00:52<00:11, 143MB/s]
#
#
# temporal_attention.ckpt:  69% 3.52G/5.11G [00:52<00:10, 155MB/s]
#
#
# temporal_attention.ckpt:  69% 3.54G/5.11G [00:52<00:09, 165MB/s]
#
#
# temporal_attention.ckpt:  70% 3.57G/5.11G [00:52<00:08, 175MB/s]
#
#
# temporal_attention.ckpt:  70% 3.60G/5.11G [00:52<00:08, 183MB/s]
#
#
# temporal_attention.ckpt:  71% 3.63G/5.11G [00:52<00:07, 194MB/s]
#
#
# temporal_attention.ckpt:  72% 3.66G/5.11G [00:52<00:07, 200MB/s]
#
#
# temporal_attention.ckpt:  72% 3.69G/5.11G [00:52<00:06, 206MB/s]
#
#
# temporal_attention.ckpt:  73% 3.71G/5.11G [00:53<00:06, 205MB/s]
#
#
# temporal_attention.ckpt:  73% 3.73G/5.11G [00:53<00:06, 201MB/s]
#
#
# temporal_attention.ckpt:  74% 3.76G/5.11G [00:53<00:06, 201MB/s]
#
#
# temporal_attention.ckpt:  74% 3.79G/5.11G [00:53<00:06, 201MB/s]
#
#
# temporal_attention.ckpt:  75% 3.82G/5.11G [00:55<00:27, 47.3MB/s]
#
#
# temporal_attention.ckpt:  75% 3.84G/5.11G [00:56<00:36, 34.7MB/s]
#
#
# temporal_attention.ckpt:  76% 3.86G/5.11G [00:56<00:28, 44.3MB/s]
#
#
# temporal_attention.ckpt:  76% 3.88G/5.11G [00:56<00:24, 51.1MB/s]
#
#
# temporal_attention.ckpt:  76% 3.90G/5.11G [00:56<00:18, 64.7MB/s]
#
#
# temporal_attention.ckpt:  77% 3.92G/5.11G [00:56<00:16, 70.5MB/s]
#
#
# temporal_attention.ckpt:  77% 3.94G/5.11G [00:57<00:16, 70.0MB/s]
#
#
# temporal_attention.ckpt:  78% 3.96G/5.11G [00:57<00:13, 84.3MB/s]
#
#
# temporal_attention.ckpt:  78% 3.98G/5.11G [00:57<00:14, 79.8MB/s]
#
#
# temporal_attention.ckpt:  78% 4.01G/5.11G [00:57<00:11, 93.6MB/s]
#
#
# temporal_attention.ckpt:  79% 4.03G/5.11G [00:57<00:12, 89.1MB/s]
#
#
# temporal_attention.ckpt:  79% 4.05G/5.11G [00:58<00:10, 106MB/s]
#
#
# temporal_attention.ckpt:  80% 4.07G/5.11G [00:58<00:08, 122MB/s]
#
#
# temporal_attention.ckpt:  80% 4.09G/5.11G [00:58<00:07, 139MB/s]
#
#
# temporal_attention.ckpt:  80% 4.11G/5.11G [00:58<00:06, 155MB/s]
#
#
# temporal_attention.ckpt:  81% 4.13G/5.11G [00:58<00:05, 166MB/s]
#
#
# temporal_attention.ckpt:  81% 4.15G/5.11G [00:58<00:05, 165MB/s]
#
#
# temporal_attention.ckpt:  82% 4.17G/5.11G [00:58<00:05, 174MB/s]
#
#
# temporal_attention.ckpt:  82% 4.19G/5.11G [00:58<00:05, 179MB/s]
#
#
# temporal_attention.ckpt:  82% 4.22G/5.11G [00:58<00:04, 186MB/s]
#
#
# temporal_attention.ckpt:  83% 4.24G/5.11G [00:59<00:14, 62.3MB/s]
#
#
# temporal_attention.ckpt:  83% 4.26G/5.11G [01:01<00:26, 32.8MB/s]
#
#
# temporal_attention.ckpt:  84% 4.29G/5.11G [01:01<00:16, 49.0MB/s]
#
#
# temporal_attention.ckpt:  84% 4.31G/5.11G [01:01<00:14, 56.8MB/s]
#
#
# temporal_attention.ckpt:  85% 4.33G/5.11G [01:01<00:11, 69.8MB/s]
#
#
# temporal_attention.ckpt:  85% 4.36G/5.11G [01:01<00:08, 93.3MB/s]
#
#
# temporal_attention.ckpt:  86% 4.39G/5.11G [01:01<00:06, 115MB/s]
#
#
# temporal_attention.ckpt:  86% 4.41G/5.11G [01:02<00:05, 123MB/s]
#
#
# temporal_attention.ckpt:  87% 4.44G/5.11G [01:02<00:04, 135MB/s]
#
#
# temporal_attention.ckpt:  87% 4.46G/5.11G [01:02<00:04, 150MB/s]
#
#
# temporal_attention.ckpt:  88% 4.48G/5.11G [01:02<00:03, 160MB/s]
#
#
# temporal_attention.ckpt:  88% 4.51G/5.11G [01:02<00:03, 178MB/s]
#
#
# temporal_attention.ckpt:  89% 4.54G/5.11G [01:02<00:03, 190MB/s]
#
#
# temporal_attention.ckpt:  89% 4.56G/5.11G [01:02<00:02, 193MB/s]
#
#
# temporal_attention.ckpt:  90% 4.59G/5.11G [01:02<00:02, 202MB/s]
#
#
# temporal_attention.ckpt:  90% 4.61G/5.11G [01:02<00:02, 203MB/s]
#
#
# temporal_attention.ckpt:  91% 4.63G/5.11G [01:03<00:02, 203MB/s]
#
#
# temporal_attention.ckpt:  91% 4.66G/5.11G [01:03<00:02, 194MB/s]
#
#
# temporal_attention.ckpt:  92% 4.69G/5.11G [01:03<00:02, 200MB/s]
#
#
# temporal_attention.ckpt:  92% 4.72G/5.11G [01:03<00:01, 205MB/s]
#
#
# temporal_attention.ckpt:  93% 4.75G/5.11G [01:03<00:01, 207MB/s]
#
#
# temporal_attention.ckpt:  93% 4.77G/5.11G [01:03<00:01, 206MB/s]
#
#
# temporal_attention.ckpt:  94% 4.79G/5.11G [01:03<00:01, 201MB/s]
#
#
# temporal_attention.ckpt:  94% 4.81G/5.11G [01:03<00:01, 200MB/s]
#
#
# temporal_attention.ckpt:  95% 4.83G/5.11G [01:04<00:01, 200MB/s]
#
#
# temporal_attention.ckpt:  95% 4.85G/5.11G [01:04<00:01, 200MB/s]
#
#
# temporal_attention.ckpt:  95% 4.88G/5.11G [01:04<00:01, 200MB/s]
#
#
# temporal_attention.ckpt:  96% 4.91G/5.11G [01:04<00:00, 204MB/s]
#
#
# temporal_attention.ckpt:  96% 4.93G/5.11G [01:04<00:00, 200MB/s]
#
#
# temporal_attention.ckpt:  97% 4.96G/5.11G [01:04<00:00, 203MB/s]
#
#
# temporal_attention.ckpt:  98% 4.99G/5.11G [01:04<00:00, 208MB/s]
#
#
# temporal_attention.ckpt:  98% 5.02G/5.11G [01:04<00:00, 213MB/s]
#
#
# temporal_attention.ckpt:  99% 5.05G/5.11G [01:05<00:00, 208MB/s]
#
#
# temporal_attention.ckpt:  99% 5.08G/5.11G [01:05<00:00, 203MB/s]
#
#
# temporal_attention.ckpt: 100% 5.11G/5.11G [01:05<00:00, 78.1MB/s]
# Fetching 7 files: 100% 7/7 [01:06<00:00,  9.50s/it]
# Initializing MagicAnimate Pipeline...
# loaded temporal unet's pretrained weights from /content/MagicAnimate-hf/stable-diffusion-v1-5/unet ...
# ### missing keys: 560;
# ### unexpected keys: 0;
# ### Temporal Module Parameters: 417.1376 M
# The config attributes {'addition_embed_type': None, 'addition_embed_type_num_heads': 64, 'addition_time_embed_dim': None, 'conditioning_channels': 3, 'encoder_hid_dim': None, 'encoder_hid_dim_type': None, 'global_pool_conditions': False, 'num_attention_heads': None, 'transformer_layers_per_block': 1} were passed to ControlNetModel, but are not expected and will be ignored. Please verify your config.json configuration file.
# It is recommended to provide `attention_head_dim` when calling `get_down_block`. Defaulting `attention_head_dim` to 8.
# It is recommended to provide `attention_head_dim` when calling `get_down_block`. Defaulting `attention_head_dim` to 8.
# It is recommended to provide `attention_head_dim` when calling `get_down_block`. Defaulting `attention_head_dim` to 8.
# It is recommended to provide `attention_head_dim` when calling `get_down_block`. Defaulting `attention_head_dim` to 8.
# /content/MagicAnimate-hf/magicanimate/pipelines/pipeline_animation.py:103: FutureWarning: The configuration file of this scheduler: DDIMScheduler {
#   "_class_name": "DDIMScheduler",
#   "_diffusers_version": "0.21.4",
#   "beta_end": 0.012,
#   "beta_schedule": "linear",
#   "beta_start": 0.00085,
#   "clip_sample": true,
#   "clip_sample_range": 1.0,
#   "dynamic_thresholding_ratio": 0.995,
#   "num_train_timesteps": 1000,
#   "prediction_type": "epsilon",
#   "rescale_betas_zero_snr": false,
#   "sample_max_value": 1.0,
#   "set_alpha_to_one": true,
#   "steps_offset": 0,
#   "thresholding": false,
#   "timestep_spacing": "leading",
#   "trained_betas": null
# }
#  is outdated. `steps_offset` should be set to 1 instead of 0. Please make sure to update the config accordingly as leaving `steps_offset` might led to incorrect results in future versions. If you have downloaded this checkpoint from the Hugging Face Hub, it would be very nice if you could open a Pull request for the `scheduler/scheduler_config.json` file
#   deprecate("steps_offset!=1", "1.0.0", deprecation_message, standard_warn=False)
# /content/MagicAnimate-hf/magicanimate/pipelines/pipeline_animation.py:116: FutureWarning: The configuration file of this scheduler: DDIMScheduler {
#   "_class_name": "DDIMScheduler",
#   "_diffusers_version": "0.21.4",
#   "beta_end": 0.012,
#   "beta_schedule": "linear",
#   "beta_start": 0.00085,
#   "clip_sample": true,
#   "clip_sample_range": 1.0,
#   "dynamic_thresholding_ratio": 0.995,
#   "num_train_timesteps": 1000,
#   "prediction_type": "epsilon",
#   "rescale_betas_zero_snr": false,
#   "sample_max_value": 1.0,
#   "set_alpha_to_one": true,
#   "steps_offset": 1,
#   "thresholding": false,
#   "timestep_spacing": "leading",
#   "trained_betas": null
# }
#  has not set the configuration `clip_sample`. `clip_sample` should be set to False in the configuration file. Please make sure to update the config accordingly as not setting `clip_sample` in the config might lead to incorrect results in future versions. If you have downloaded this checkpoint from the Hugging Face Hub, it would be very nice if you could open a Pull request for the `scheduler/scheduler_config.json` file
#   deprecate("clip_sample not set", "1.0.0", deprecation_message, standard_warn=False)
# Initialization Done!
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://03e6411805441f5a99.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# /content/MagicAnimate-hf/magicanimate/pipelines/pipeline_animation.py:624: FutureWarning: Accessing config attribute `in_channels` directly via 'UNet3DConditionModel' object attribute is deprecated. Please access 'in_channels' over 'UNet3DConditionModel's config object instead, e.g. 'unet.config.in_channels'.
#   num_channels_latents = self.unet.in_channels
# 100% 25/25 [06:27<00:00, 15.51s/it]
# 100% 48/48 [00:08<00:00,  5.70it/s]
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (1544, 516) to (1552, 528) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# [swscaler @ 0x7148800] Warning: data is not aligned! This can lead to a speed loss
# /content/MagicAnimate-hf/magicanimate/pipelines/pipeline_animation.py:624: FutureWarning: Accessing config attribute `in_channels` directly via 'UNet3DConditionModel' object attribute is deprecated. Please access 'in_channels' over 'UNet3DConditionModel's config object instead, e.g. 'unet.config.in_channels'.
#   num_channels_latents = self.unet.in_channels
# 100% 25/25 [16:02<00:00, 38.48s/it]
# 100% 112/112 [00:20<00:00,  5.48it/s]
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (1544, 516) to (1552, 528) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# [swscaler @ 0x6e10800] Warning: data is not aligned! This can lead to a speed loss
# Keyboard interruption in main thread... closing server.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 2194, in block_thread
#     time.sleep(0.1)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/MagicAnimate-hf/app.py", line 104, in <module>
#     demo.launch(share=True)
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 2101, in launch
#     self.block_thread()
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 2198, in block_thread
#     self.server.close()
#   File "/usr/local/lib/python3.10/dist-packages/gradio/networking.py", line 75, in close
#     self.thread.join()
#   File "/usr/lib/python3.10/threading.py", line 1096, in join
#     self._wait_for_tstate_lock()
#   File "/usr/lib/python3.10/threading.py", line 1116, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
# KeyboardInterrupt
# Killing tunnel 127.0.0.1:7860 <> https://03e6411805441f5a99.gradio.live
